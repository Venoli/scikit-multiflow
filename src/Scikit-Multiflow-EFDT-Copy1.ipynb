# %%
# %matplotlib notebook

# %%
# %load_ext autoreload

# %autoreload 2

# %%
from asips.asips_delayed_progressive import Asips
asips = Asips()
# Out:
# -------READ CSV-------
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
#      Mean of the integrated profile  \
# 301                      118.851562
# 302                      101.023438
# 303                      107.070312
# 304                      131.945312
# 305                      127.093750
#
#      Standard deviation of the integrated profile  \
# 301                                     39.905374
# 302                                     52.064333
# 303                                     47.729247
# 304                                     48.760145
# 305                                     54.602031
#
#      Excess kurtosis of the integrated profile  \
# 301                                   0.342266
# 302                                   0.296000
# 303                                   0.546229
# 304                                  -0.170860
# 305                                   0.004681
#
#      Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 301                            0.408057                  1.811873
# 302                           -0.108197                  1.803512
# 303                            0.430071                  3.990803
# 304                           -0.286805                  2.846154
# 305                           -0.544766                  2.206522
#
#      Standard deviation of the DM-SNR curve  \
# 301                               15.281218
# 302                               12.259896
# 303                               25.756463
# 304                               17.445608
# 305                               14.110410
#
#      Excess kurtosis of the DM-SNR curve  Skewness of the DM-SNR curve  \
# 301                            10.218044                    120.638361
# 302                            11.113283                    174.258560
# 303                             7.122971                     52.715586
# 304                             8.064323                     78.326687
# 305                             9.767350                    123.607601
#
#      target_class
# 301             0
# 302             0
# 303             0
# 304             0
# 305             0
# -------INIT STREAMS-------

# %%
#Pretrain
asips.pretrain()
# Out:
# -------PRETRAIN STARTED-------
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# -------PRETRAIN FINISHED-------
# Time difference: 0:00:00.188951
# info: <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
#  Number of learning samples: 300
# "Time difference: 0:00:00.188951 \ninfo: <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,\n                                    leaf_prediction='nba',\n                                    max_byte_size=33554432,\n                                    memory_estimate_period=1000000,\n                                    min_samples_reevaluate=20, nb_threshold=0,\n                                    nominal_attributes=None,\n                                    split_confidence=1e-07,\n                                    split_criterion='gaussian_hellinger',\n                                    stop_mem_management=False,\n                                    tie_threshold=0.05)> \n Number of learning samples: 300"

# %%
#First batch
asips.make_prediction(asips.stream_first)
# Out:
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  -------------------- [0%] [0.00s]{'name': '-MYe7iXkayGGDf1_9nR9'}
#  #########----------- [45%] [1.29s]{'name': '-MYe7iprN1wuq7PnrME1'}
#  ##########---------- [50%] [2.50s]{'name': '-MYe7j82B2P9udrr52_v'}
#  ################---- [80%] [3.66s]{'name': '-MYe7jg3dj_syjfT44HY'}
#  #################### [99%] [5.99s]
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9700
# M0 - Kappa        : 0.5562
# 17
# M0 - Precision: 0.6667
# M0 - Recall: 0.5000
# M0 - F1 score: 0.5714
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.02
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# 17
# Kappa: 0.6428571428571426
# G-Mean: 0.6428571428571426
# Accuracy: 0.7071067811865476
# Recall: 0.95
# Precision: 0.5
# F1 Score: 1.0
# 'Kappa: 0.6428571428571426 \nG-Mean: 0.6428571428571426 \nAccuracy: 0.7071067811865476 \nRecall: 0.95 \nPrecision: 0.5 \nF1 Score: 1.0'

# %%
asips.make_prediction(asips.stream_second)
# Out:
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  #------------------- [5%] [0.01s]{'name': '-MY_XLpxzQgOSi_UZAq4'}
# {'name': '-MY_XM8Ih0MoBroz4KV2'}
#  ####---------------- [20%] [2.64s]{'name': '-MY_XMRPqMDYrHe1zQ_a'}
#  ######-------------- [30%] [3.77s]{'name': '-MY_XMiEixEaLKMUv1q6'}
#  #######------------- [35%] [4.99s]{'name': '-MY_XN0UZr5tiNT5TIIn'}
#  ##########---------- [50%] [6.22s]{'name': '-MY_XNJg1GAlyqREN24X'}
#  #############------- [65%] [7.45s]{'name': '-MY_XNc2YjlrONZq6YS_'}
#  ##############------ [70%] [8.67s]{'name': '-MY_XNunJzNZuNhA62sp'}
# {'name': '-MY_XODAdP6wGuiDyaxw'}
#  ###################- [95%] [11.13s]{'name': '-MY_XOWGkWMSEwc81D72'}
#  #################### [99%] [12.27s]
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9800
# M0 - Kappa        : 0.8890
# 11
# M0 - Precision: 1.0000
# M0 - Recall: 0.8182
# M0 - F1 score: 0.9000
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.03
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# 11
# Kappa: 1.0
# G-Mean: 1.0
# Accuracy: 1.0
# Recall: 1.0
# Precision: 1.0
# F1 Score: 1.0

# %%
asips.make_prediction(asips.stream_second)
# Out:
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  #------------------- [5%] [0.00s]{'name': '-MYTjrUE4s6S1s5MZm3S'}
# {'name': '-MYTjrmK54_YECcc_tmB'}
#  ####---------------- [20%] [2.55s]{'name': '-MYTjs4R5zGrlJGXJJTJ'}
#  ######-------------- [30%] [3.69s]{'name': '-MYTjsMEmoQUWmiguwI9'}
#  #######------------- [35%] [4.84s]{'name': '-MYTjsc55hWYoW1aWxf-'}
#  ##########---------- [50%] [5.91s]{'name': '-MYTjsuN0DneBxk00kBt'}
#  #############------- [65%] [7.16s]{'name': '-MYTjtBeCnfZ_OOVLOF8'}
#  ##############------ [70%] [8.25s]{'name': '-MYTjtUI03fJrZBaUMhm'}
# {'name': '-MYTjtmAfeVm5J8TuQB2'}
#  ###################- [95%] [10.75s]{'name': '-MYTju4Zf5lelJ-3Q9gu'}
#  #################### [99%] [11.97s]
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9800
# M0 - Kappa        : 0.8890
# M0 - Precision: 1.0000
# M0 - Recall: 0.8182
# M0 - F1 score: 0.9000
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.03
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Accuracy: 1.0
# Recall: 1.0
# Precision: 1.0
# F1 Score: 1.0
# Specificity(TNR): 1.0
# G-Mean: 1.0

# %%
# from asips_delayed_progressive import Asips
# asips = Asips()
asips.learn('-MYXVO10LSS4_ZWaKpKR')
# Out:
# {'excessKurtosisOfTheDMSNRCurve': 4.652341839, 'excessKurtosisOfTheIntegratedProfile': 2.478374846, 'meanOfTheDMSNRCurve': 8.230769231, 'meanOfTheIntegratedProfile': 52.3359375, 'skewnessOfTheDMSNRCurve': 21.98788225, 'skewnessOfTheIntegratedProfile': 10.17917088, 'standardDeviationOfTheDMSNRCurve': 34.77594683, 'standardDeviationOfTheIntegratedProfile': 34.77500839, 'targetClass': 1, 'yPred': 1}
# {"excessKurtosisOfTheDMSNRCurve": 4.652341839, "excessKurtosisOfTheIntegratedProfile": 2.478374846, "meanOfTheDMSNRCurve": 8.230769231, "meanOfTheIntegratedProfile": 52.3359375, "skewnessOfTheDMSNRCurve": 21.98788225, "skewnessOfTheIntegratedProfile": 10.17917088, "standardDeviationOfTheDMSNRCurve": 34.77594683, "standardDeviationOfTheIntegratedProfile": 34.77500839, "targetClass": 1, "yPred": 1}
# jjjj
#    Mean of the integrated profile  \
# 0                        4.652342
#
#    Standard deviation of the integrated profile  \
# 0                                      2.478375
#
#    Excess kurtosis of the integrated profile  \
# 0                                   8.230769
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                           52.335938                 21.987882
#
#    Standard deviation of the DM-SNR curve  \
# 0                               10.179171
#
#    Excess kurtosis of the DM-SNR curve  Skewness of the DM-SNR curve  \
# 0                            34.775947                     34.775008
#
#    target_class  y_pred
# 0             1       1
#    Mean of the integrated profile  \
# 0                        4.652342
#
#    Standard deviation of the integrated profile  \
# 0                                      2.478375
#
#    Excess kurtosis of the integrated profile  \
# 0                                   8.230769
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                           52.335938                 21.987882
#
#    Standard deviation of the DM-SNR curve  \
# 0                               10.179171
#
#    Excess kurtosis of the DM-SNR curve  Skewness of the DM-SNR curve  \
# 0                            34.775947                     34.775008
#
#    target_class
# 0             1
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 0:00:00.004928 Time difference
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>

# %%
asips.learn_from_all()
# Out:
# {"-MYXVFtx5uXnSuyIaf0d": {"excessKurtosisOfTheDMSNRCurve": 2.2292447280000003, "excessKurtosisOfTheIntegratedProfile": 3.6477399239999997, "meanOfTheDMSNRCurve": 33.86036789, "meanOfTheIntegratedProfile": 50.9296875, "skewnessOfTheDMSNRCurve": 4.419700221, "skewnessOfTheIntegratedProfile": 17.38148313, "standardDeviationOfTheDMSNRCurve": 57.92865293, "standardDeviationOfTheIntegratedProfile": 32.59413856, "targetClass": 1, "yPred": 1}, "-MYXVGCLwILdLbHJ-6OW": {"excessKurtosisOfTheDMSNRCurve": 8.359921014, "excessKurtosisOfTheIntegratedProfile": 0.53599405, "meanOfTheDMSNRCurve": 2.8979933110000005, "meanOfTheIntegratedProfile": 95.6640625, "skewnessOfTheDMSNRCurve": 88.1807417, "skewnessOfTheIntegratedProfile": 0.535184976, "standardDeviationOfTheDMSNRCurve": 16.51930955, "standardDeviationOfTheIntegratedProfile": 47.60650516, "targetClass": 0, "yPred": 0}, "-MYXVGVT3hYLGCvRGqNm": {"excessKurtosisOfTheDMSNRCurve": 5.018115302, "excessKurtosisOfTheIntegratedProfile": 1.391329691, "meanOfTheDMSNRCurve": 8.022575251000001, "meanOfTheIntegratedProfile": 72.5859375, "skewnessOfTheDMSNRCurve": 25.03925564, "skewnessOfTheIntegratedProfile": 4.420335099999999, "standardDeviationOfTheDMSNRCurve": 37.46327511, "standardDeviationOfTheIntegratedProfile": 39.65663708, "targetClass": 0, "yPred": 1}, "-MYXVGnrP5N1O3jVqr_y": {"excessKurtosisOfTheDMSNRCurve": 0.295248594, "excessKurtosisOfTheIntegratedProfile": 6.187429415, "meanOfTheDMSNRCurve": 121.367893, "meanOfTheIntegratedProfile": 6.4140625, "skewnessOfTheDMSNRCurve": -1.027613812, "skewnessOfTheIntegratedProfile": 40.10131647, "standardDeviationOfTheDMSNRCurve": 61.4164204, "standardDeviationOfTheIntegratedProfile": 30.92014092, "targetClass": 1, "yPred": 1}, "-MYXVOIVGf7NFxEw7nMf": {"excessKurtosisOfTheDMSNRCurve": 1.389508736, "excessKurtosisOfTheIntegratedProfile": 1.118794002, "meanOfTheDMSNRCurve": 42.4138796, "meanOfTheIntegratedProfile": 102.46875, "skewnessOfTheDMSNRCurve": 0.35152827299999995, "skewnessOfTheI
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# 0:00:00.012570 Time difference
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>

# %%
asips.learn_from_all()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-ee2cac244980> in <module>
# ----> 1 asips.learn_from_all()
#
# ~/Documents/FYP/Implementation/Asips/scikit-multiflow/src/asips_delayed_progressive.py in learn_from_all(self)
#     132         # convert to a dataframe
#     133         dataframe = pd.DataFrame.from_dict(j, orient='columns')
# --> 134         dataframe.columns = asips_utils.DATAFRAME_HEAD
#     135         print(dataframe)
#     136
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     224
#     225         if new_len != old_len:
# --> 226             raise ValueError(
#     227                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     228                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 8 elements, new values have 10 elements

# %%
# !python flask_api.py
# Out:
#  * Serving Flask app "flask_api" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# -------READ CSV-------
# Shape of new partitioned dataframes - (300, 9) , (50, 9),(4350, 9)
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------STREAMS STARTING-------
# -------PRETRAIN STARTED-------
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# 300 samples analyzed.
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# -------PRETRAIN FINISHED-------
# <_MainProcess name='MainProcess' parent=None started>
# {'name': '-MYGiw02oDHf82eifLws'}
# {'name': '-MYGiwJ09NZQtuwdZ7JX'}
# {'name': '-MYGiw_vaIVB0Iw1WmtL'}
# 50 samples analyzed.
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Accuracy: 1.0
# Recall: 1.0
# Precision: 1.0
# F1 Score: 1.0
# Specificity(TNR): 1.0
# G-Mean: 1.0
# {'name': '-MYGiwsxaPQ66CZ0vGj6'}
# 127.0.0.1 - - [15/Apr/2021 00:24:09] "GET / HTTP/1.1" 200 -
# ^C

# %% [markdown]
# ### API Testing

# %%
cd asips
# Out:
# /Users/venoligamage/Documents/FYP/Implementation/Asips/scikit-multiflow/src/asips

# %%
from asips.asips_delayed_progressive import Asips
asips = Asips()
asips.x()
# Out:
# -------READ CSV-------
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
#      Mean of the integrated profile  \
# 301                      118.851562
# 302                      101.023438
# 303                      107.070312
# 304                      131.945312
# 305                      127.093750
#
#      Standard deviation of the integrated profile  \
# 301                                     39.905374
# 302                                     52.064333
# 303                                     47.729247
# 304                                     48.760145
# 305                                     54.602031
#
#      Excess kurtosis of the integrated profile  \
# 301                                   0.342266
# 302                                   0.296000
# 303                                   0.546229
# 304                                  -0.170860
# 305                                   0.004681
#
#      Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 301                            0.408057                  1.811873
# 302                           -0.108197                  1.803512
# 303                            0.430071                  3.990803
# 304                           -0.286805                  2.846154
# 305                           -0.544766                  2.206522
#
#      Standard deviation of the DM-SNR curve  \
# 301                               15.281218
# 302                               12.259896
# 303                               25.756463
# 304                               17.445608
# 305                               14.110410
#
#      Excess kurtosis of the DM-SNR curve  Skewness of the DM-SNR curve  \
# 301                            10.218044                    120.638361
# 302                            11.113283                    174.258560
# 303                             7.122971                     52.715586
# 304                             8.064323                     78.326687
# 305                             9.767350                    123.607601
#
#      target_class
# 301             0
# 302             0
# 303             0
# 304             0
# 305             0
# -------INIT STREAMS-------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-f0252ddb6e76> in <module>
#       1 from asips.asips_delayed_progressive import Asips
#       2 asips = Asips()
# ----> 3 asips.x()
#
# AttributeError: 'Asips' object has no attribute 'x'

# %%
from test_with_other_classifiers import TestWithOtherClassifiers
test_other = TestWithOtherClassifiers()
log = test_other.classification_pipeline('under_over_bagging')
# Out:
#    Mean of the integrated profile  \
# 0                      121.156250
# 1                       76.968750
# 2                      130.585938
# 3                       84.804688
# 4                      109.406250
#
#    Standard deviation of the integrated profile  \
# 0                                     48.372971
# 1                                     36.175557
# 2                                     53.229534
# 3                                     36.117659
# 4                                     55.912521
#
#    Excess kurtosis of the integrated profile  \
# 0                                   0.375485
# 1                                   0.712898
# 2                                   0.133408
# 3                                   0.825013
# 4                                   0.565106
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                           -0.013165                  3.168896
# 1                            3.388719                  2.399666
# 2                           -0.297242                  2.743311
# 3                            3.274125                  2.790134
# 4                            0.056247                  2.797659
#
#    Standard deviation of the DM-SNR curve  \
# 0                               18.399367
# 1                               17.570997
# 2                               22.362553
# 3                               20.618009
# 4                               19.496527
#
#    Excess kurtosis of the DM-SNR curve  Skewness of the DM-SNR curve  \
# 0                             7.449874                     65.159298
# 1                             9.414652                    102.722975
# 2                             8.508364                     74.031324
# 3                             8.405008                     76.291128
# 4                             9.443282                     97.374578
#
#    target_class
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# 333333333333
# {"-MYlvuN95ddxj0Tly3FR": {"excessKurtosisOfTheDMSNRCurve": 7.247670151, "excessKurtosisOfTheIntegratedProfile": 0.7442031720000001, "meanOfTheDMSNRCurve": 3.22826087, "meanOfTheIntegratedProfile": 76.8515625, "skewnessOfTheDMSNRCurve": 56.44359608, "skewnessOfTheIntegratedProfile": 1.4641748069999998, "smoteBagging": 1, "standardDeviationOfTheDMSNRCurve": 21
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvuNA6QWJ2j4ZA897
# {'excessKurtosisOfTheDMSNRCurve': -0.713518139, 'excessKurtosisOfTheIntegratedProfile': -0.111229859, 'meanOfTheDMSNRCurve': 117.37792639999999, 'meanOfTheIntegratedProfile': 135.2734375, 'skewnessOfTheDMSNRCurve': -1.3532475480000001, 'skewnessOfTheIntegratedProfile': 0.462083597, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 80.49672908, 'standardDeviationOfTheIntegratedProfile': 41.95583892, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.713518
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   -0.11123                117.377926
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      135.273438                     -1.353248
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            0.462084           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               80.496729
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     41.955839           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.713518
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   -0.11123                117.377926
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      135.273438                     -1.353248
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            0.462084                               80.496729
#
#    Standard deviation of the integrated profile  target_class
# 0                                     41.955839             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvuNA6QWJ2j4ZA898
# {'excessKurtosisOfTheDMSNRCurve': 5.018115302, 'excessKurtosisOfTheIntegratedProfile': 1.391329691, 'meanOfTheDMSNRCurve': 8.022575251000001, 'meanOfTheIntegratedProfile': 72.5859375, 'skewnessOfTheDMSNRCurve': 25.03925564, 'skewnessOfTheIntegratedProfile': 4.420335099999999, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 37.46327511, 'standardDeviationOfTheIntegratedProfile': 39.65663708, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             5.018115
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    1.39133                  8.022575
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       72.585938                     25.039256
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            4.420335           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               37.463275
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     39.656637           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             5.018115
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    1.39133                  8.022575
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       72.585938                     25.039256
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            4.420335                               37.463275
#
#    Standard deviation of the integrated profile  target_class
# 0                                     39.656637             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvuNJoUqTeBtCDzoF
# {'excessKurtosisOfTheDMSNRCurve': 2.2292447280000003, 'excessKurtosisOfTheIntegratedProfile': 3.6477399239999997, 'meanOfTheDMSNRCurve': 33.86036789, 'meanOfTheIntegratedProfile': 50.9296875, 'skewnessOfTheDMSNRCurve': 4.419700221, 'skewnessOfTheIntegratedProfile': 17.38148313, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 57.92865293, 'standardDeviationOfTheIntegratedProfile': 32.59413856, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             2.229245
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    3.64774                 33.860368
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       50.929688                        4.4197
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                           17.381483           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               57.928653
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     32.594139           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             2.229245
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    3.64774                 33.860368
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       50.929688                        4.4197
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                           17.381483                               57.928653
#
#    Standard deviation of the integrated profile  target_class
# 0                                     32.594139             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlvuNJoUqTeBtCDzoG
# {'excessKurtosisOfTheDMSNRCurve': -0.615911193, 'excessKurtosisOfTheIntegratedProfile': 0.083238873, 'meanOfTheDMSNRCurve': 126.7299331, 'meanOfTheIntegratedProfile': 130.8359375, 'skewnessOfTheDMSNRCurve': -1.265235268, 'skewnessOfTheIntegratedProfile': -0.49444035, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 83.43642448, 'standardDeviationOfTheIntegratedProfile': 53.38199271, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.615911
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.083239                126.729933
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      130.835938                     -1.265235
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            -0.49444           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               83.436424
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     53.381993           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.615911
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.083239                126.729933
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      130.835938                     -1.265235
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            -0.49444                               83.436424
#
#    Standard deviation of the integrated profile  target_class
# 0                                     53.381993             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvugo5OEmmvWytJia
# {'excessKurtosisOfTheDMSNRCurve': 0.295248594, 'excessKurtosisOfTheIntegratedProfile': 6.187429415, 'meanOfTheDMSNRCurve': 121.367893, 'meanOfTheIntegratedProfile': 6.4140625, 'skewnessOfTheDMSNRCurve': -1.027613812, 'skewnessOfTheIntegratedProfile': 40.10131647, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 61.4164204, 'standardDeviationOfTheIntegratedProfile': 30.92014092, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             0.295249
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   6.187429                121.367893
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                        6.414062                     -1.027614
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                           40.101316           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                                61.41642
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     30.920141           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             0.295249
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   6.187429                121.367893
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                        6.414062                     -1.027614
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                           40.101316                                61.41642
#
#    Standard deviation of the integrated profile  target_class
# 0                                     30.920141             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlvugpP0F5lfjcPz4d
# {'excessKurtosisOfTheDMSNRCurve': 1.3950157980000002, 'excessKurtosisOfTheIntegratedProfile': 1.4097378459999999, 'meanOfTheDMSNRCurve': 42.98829431, 'meanOfTheIntegratedProfile': 92.890625, 'skewnessOfTheDMSNRCurve': 0.321894692, 'skewnessOfTheIntegratedProfile': 1.964645676, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 74.76461298, 'standardDeviationOfTheIntegratedProfile': 50.00066162, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             1.395016
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   1.409738                 42.988294
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       92.890625                      0.321895
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            1.964646           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               74.764613
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     50.000662           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             1.395016
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   1.409738                 42.988294
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       92.890625                      0.321895
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            1.964646                               74.764613
#
#    Standard deviation of the integrated profile  target_class
# 0                                     50.000662             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlvyY0U2WFmZcng7dt
# {'excessKurtosisOfTheDMSNRCurve': 5.018115302, 'excessKurtosisOfTheIntegratedProfile': 1.391329691, 'meanOfTheDMSNRCurve': 8.022575251000001, 'meanOfTheIntegratedProfile': 72.5859375, 'skewnessOfTheDMSNRCurve': 25.03925564, 'skewnessOfTheIntegratedProfile': 4.420335099999999, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 37.46327511, 'standardDeviationOfTheIntegratedProfile': 39.65663708, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             5.018115
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    1.39133                  8.022575
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       72.585938                     25.039256
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            4.420335           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               37.463275
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     39.656637           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             5.018115
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    1.39133                  8.022575
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       72.585938                     25.039256
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            4.420335                               37.463275
#
#    Standard deviation of the integrated profile  target_class
# 0                                     39.656637             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvyY1FJDX13CRBkNo
# {'excessKurtosisOfTheDMSNRCurve': -0.615911193, 'excessKurtosisOfTheIntegratedProfile': 0.083238873, 'meanOfTheDMSNRCurve': 126.7299331, 'meanOfTheIntegratedProfile': 130.8359375, 'skewnessOfTheDMSNRCurve': -1.265235268, 'skewnessOfTheIntegratedProfile': -0.49444035, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 83.43642448, 'standardDeviationOfTheIntegratedProfile': 53.38199271, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.615911
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.083239                126.729933
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      130.835938                     -1.265235
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            -0.49444           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               83.436424
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     53.381993           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.615911
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.083239                126.729933
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      130.835938                     -1.265235
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            -0.49444                               83.436424
#
#    Standard deviation of the integrated profile  target_class
# 0                                     53.381993             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvyY41kboGn3UKIx4
# {'excessKurtosisOfTheDMSNRCurve': 7.247670151, 'excessKurtosisOfTheIntegratedProfile': 0.7442031720000001, 'meanOfTheDMSNRCurve': 3.22826087, 'meanOfTheIntegratedProfile': 76.8515625, 'skewnessOfTheDMSNRCurve': 56.44359608, 'skewnessOfTheIntegratedProfile': 1.4641748069999998, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 21.03621429, 'standardDeviationOfTheIntegratedProfile': 41.49982866, 'targetClass': 0, 'yPred': 0}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                              7.24767
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.744203                  3.228261
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       76.851562                     56.443596
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            1.464175           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               21.036214
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     41.499829           0.0     0.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                              7.24767
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.744203                  3.228261
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       76.851562                     56.443596
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            1.464175                               21.036214
#
#    Standard deviation of the integrated profile  target_class
# 0                                     41.499829             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvyYEygDGeb_XGkg1
# {'excessKurtosisOfTheDMSNRCurve': -0.713518139, 'excessKurtosisOfTheIntegratedProfile': -0.111229859, 'meanOfTheDMSNRCurve': 117.37792639999999, 'meanOfTheIntegratedProfile': 135.2734375, 'skewnessOfTheDMSNRCurve': -1.3532475480000001, 'skewnessOfTheIntegratedProfile': 0.462083597, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 80.49672908, 'standardDeviationOfTheIntegratedProfile': 41.95583892, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.713518
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   -0.11123                117.377926
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      135.273438                     -1.353248
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            0.462084           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               80.496729
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     41.955839           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.713518
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   -0.11123                117.377926
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      135.273438                     -1.353248
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            0.462084                               80.496729
#
#    Standard deviation of the integrated profile  target_class
# 0                                     41.955839             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvyYFq5EL7ACvbkWP
# {'excessKurtosisOfTheDMSNRCurve': 2.2292447280000003, 'excessKurtosisOfTheIntegratedProfile': 3.6477399239999997, 'meanOfTheDMSNRCurve': 33.86036789, 'meanOfTheIntegratedProfile': 50.9296875, 'skewnessOfTheDMSNRCurve': 4.419700221, 'skewnessOfTheIntegratedProfile': 17.38148313, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 57.92865293, 'standardDeviationOfTheIntegratedProfile': 32.59413856, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             2.229245
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    3.64774                 33.860368
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       50.929688                        4.4197
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                           17.381483           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               57.928653
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     32.594139           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             2.229245
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    3.64774                 33.860368
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       50.929688                        4.4197
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                           17.381483                               57.928653
#
#    Standard deviation of the integrated profile  target_class
# 0                                     32.594139             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlvyqFbMLkHDp-_KTh
# {'excessKurtosisOfTheDMSNRCurve': 1.3950157980000002, 'excessKurtosisOfTheIntegratedProfile': 1.4097378459999999, 'meanOfTheDMSNRCurve': 42.98829431, 'meanOfTheIntegratedProfile': 92.890625, 'skewnessOfTheDMSNRCurve': 0.321894692, 'skewnessOfTheIntegratedProfile': 1.964645676, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 74.76461298, 'standardDeviationOfTheIntegratedProfile': 50.00066162, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             1.395016
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   1.409738                 42.988294
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       92.890625                      0.321895
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            1.964646           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               74.764613
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     50.000662           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             1.395016
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   1.409738                 42.988294
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       92.890625                      0.321895
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            1.964646                               74.764613
#
#    Standard deviation of the integrated profile  target_class
# 0                                     50.000662             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlvyqFbMLkHDp-_KTi
# {'excessKurtosisOfTheDMSNRCurve': 0.295248594, 'excessKurtosisOfTheIntegratedProfile': 6.187429415, 'meanOfTheDMSNRCurve': 121.367893, 'meanOfTheIntegratedProfile': 6.4140625, 'skewnessOfTheDMSNRCurve': -1.027613812, 'skewnessOfTheIntegratedProfile': 40.10131647, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 61.4164204, 'standardDeviationOfTheIntegratedProfile': 30.92014092, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             0.295249
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   6.187429                121.367893
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                        6.414062                     -1.027614
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                           40.101316           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                                61.41642
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     30.920141           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             0.295249
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   6.187429                121.367893
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                        6.414062                     -1.027614
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                           40.101316                                61.41642
#
#    Standard deviation of the integrated profile  target_class
# 0                                     30.920141             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlw0fVY6526X42rlme
# {'excessKurtosisOfTheDMSNRCurve': 5.018115302, 'excessKurtosisOfTheIntegratedProfile': 1.391329691, 'meanOfTheDMSNRCurve': 8.022575251000001, 'meanOfTheIntegratedProfile': 72.5859375, 'skewnessOfTheDMSNRCurve': 25.03925564, 'skewnessOfTheIntegratedProfile': 4.420335099999999, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 37.46327511, 'standardDeviationOfTheIntegratedProfile': 39.65663708, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             5.018115
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    1.39133                  8.022575
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       72.585938                     25.039256
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            4.420335           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               37.463275
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     39.656637           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             5.018115
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    1.39133                  8.022575
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       72.585938                     25.039256
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            4.420335                               37.463275
#
#    Standard deviation of the integrated profile  target_class
# 0                                     39.656637             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlw0fVY6526X42rlmf
# {'excessKurtosisOfTheDMSNRCurve': 7.247670151, 'excessKurtosisOfTheIntegratedProfile': 0.7442031720000001, 'meanOfTheDMSNRCurve': 3.22826087, 'meanOfTheIntegratedProfile': 76.8515625, 'skewnessOfTheDMSNRCurve': 56.44359608, 'skewnessOfTheIntegratedProfile': 1.4641748069999998, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 21.03621429, 'standardDeviationOfTheIntegratedProfile': 41.49982866, 'targetClass': 0, 'yPred': 0}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                              7.24767
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.744203                  3.228261
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       76.851562                     56.443596
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            1.464175           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               21.036214
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     41.499829           0.0     0.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                              7.24767
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.744203                  3.228261
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       76.851562                     56.443596
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            1.464175                               21.036214
#
#    Standard deviation of the integrated profile  target_class
# 0                                     41.499829             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlw0fVY6526X42rlmg
# {'excessKurtosisOfTheDMSNRCurve': -0.615911193, 'excessKurtosisOfTheIntegratedProfile': 0.083238873, 'meanOfTheDMSNRCurve': 126.7299331, 'meanOfTheIntegratedProfile': 130.8359375, 'skewnessOfTheDMSNRCurve': -1.265235268, 'skewnessOfTheIntegratedProfile': -0.49444035, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 83.43642448, 'standardDeviationOfTheIntegratedProfile': 53.38199271, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.615911
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.083239                126.729933
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      130.835938                     -1.265235
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            -0.49444           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               83.436424
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     53.381993           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.615911
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.083239                126.729933
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      130.835938                     -1.265235
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            -0.49444                               83.436424
#
#    Standard deviation of the integrated profile  target_class
# 0                                     53.381993             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlw0feWf81tS-Yah89
# {'excessKurtosisOfTheDMSNRCurve': -0.713518139, 'excessKurtosisOfTheIntegratedProfile': -0.111229859, 'meanOfTheDMSNRCurve': 117.37792639999999, 'meanOfTheIntegratedProfile': 135.2734375, 'skewnessOfTheDMSNRCurve': -1.3532475480000001, 'skewnessOfTheIntegratedProfile': 0.462083597, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 80.49672908, 'standardDeviationOfTheIntegratedProfile': 41.95583892, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.713518
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   -0.11123                117.377926
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      135.273438                     -1.353248
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            0.462084           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               80.496729
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     41.955839           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.713518
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   -0.11123                117.377926
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      135.273438                     -1.353248
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            0.462084                               80.496729
#
#    Standard deviation of the integrated profile  target_class
# 0                                     41.955839             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlw0fh1GESmMkX-q5J
# {'excessKurtosisOfTheDMSNRCurve': 2.2292447280000003, 'excessKurtosisOfTheIntegratedProfile': 3.6477399239999997, 'meanOfTheDMSNRCurve': 33.86036789, 'meanOfTheIntegratedProfile': 50.9296875, 'skewnessOfTheDMSNRCurve': 4.419700221, 'skewnessOfTheIntegratedProfile': 17.38148313, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 57.92865293, 'standardDeviationOfTheIntegratedProfile': 32.59413856, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             2.229245
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    3.64774                 33.860368
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       50.929688                        4.4197
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                           17.381483           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               57.928653
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     32.594139           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             2.229245
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    3.64774                 33.860368
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       50.929688                        4.4197
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                           17.381483                               57.928653
#
#    Standard deviation of the integrated profile  target_class
# 0                                     32.594139             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlw0yQF_Qra_ja-Ztw
# {'excessKurtosisOfTheDMSNRCurve': 1.3950157980000002, 'excessKurtosisOfTheIntegratedProfile': 1.4097378459999999, 'meanOfTheDMSNRCurve': 42.98829431, 'meanOfTheIntegratedProfile': 92.890625, 'skewnessOfTheDMSNRCurve': 0.321894692, 'skewnessOfTheIntegratedProfile': 1.964645676, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 74.76461298, 'standardDeviationOfTheIntegratedProfile': 50.00066162, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             1.395016
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   1.409738                 42.988294
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       92.890625                      0.321895
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            1.964646           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               74.764613
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     50.000662           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             1.395016
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   1.409738                 42.988294
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       92.890625                      0.321895
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            1.964646                               74.764613
#
#    Standard deviation of the integrated profile  target_class
# 0                                     50.000662             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlw0y_6m7ZcJ26a6_M
# {'excessKurtosisOfTheDMSNRCurve': 0.295248594, 'excessKurtosisOfTheIntegratedProfile': 6.187429415, 'meanOfTheDMSNRCurve': 121.367893, 'meanOfTheIntegratedProfile': 6.4140625, 'skewnessOfTheDMSNRCurve': -1.027613812, 'skewnessOfTheIntegratedProfile': 40.10131647, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 61.4164204, 'standardDeviationOfTheIntegratedProfile': 30.92014092, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             0.295249
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   6.187429                121.367893
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                        6.414062                     -1.027614
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                           40.101316           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                                61.41642
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     30.920141           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             0.295249
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   6.187429                121.367893
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                        6.414062                     -1.027614
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                           40.101316                                61.41642
#
#    Standard deviation of the integrated profile  target_class
# 0                                     30.920141             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]

# %%
cd asips
# Out:
# /Users/venoligamage/Documents/FYP/Implementation/Asips/scikit-multiflow/src/asips

# %%
# !python flask_api.py
# Out:
# -------READ CSV-------
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
#  * Serving Flask app "flask_api" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with fsevents reloader
# -------READ CSV-------
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
#  * Debugger is active!
#  * Debugger PIN: 159-978-075
# -------PRETRAIN STARTED-------
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# <class 'datetime.timedelta'>
# -------PRETRAIN FINISHED-------
# Time difference: 0:00:00.201835
# info: <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
#  Number of learning samples: 300
#  Features: ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Target values: [0, 1]
# 127.0.0.1 - - [30/Apr/2021 22:12:22] "GET /pretrain/300 HTTP/1.1" 200 -
# -------READ CSV-------
# -------READ CSV-------
# -------READ CSV-------
# -------READ CSV-------
# -------READ CSV-------
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
# -------PRETRAIN STARTED-------
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# <class 'datetime.timedelta'>
# -------PRETRAIN FINISHED-------
# Time difference: 0:00:00.906932
# info: <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
#  Number of learning samples: 300
#  Features: ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Target values: [0, 1]
# 127.0.0.1 - - [30/Apr/2021 22:13:18] "GET /pretrain/300 HTTP/1.1" 200 -
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  #------------------- [5%] [0.00s]None
# None
#  ###----------------- [15%] [0.00s]None
#  ####---------------- [20%] [0.00s]None
# None
#  #####--------------- [25%] [0.01s]None
#  ######-------------- [30%] [0.01s]None
#  #######------------- [35%] [0.01s]None
#  ########------------ [40%] [0.01s]None
#  ##########---------- [50%] [0.01s]None
#  ###########--------- [55%] [0.01s]None
#  ############-------- [60%] [0.01s]None
#  #############------- [65%] [0.01s]None
#  ##############------ [70%] [0.01s]None
#  ###############----- [75%] [0.01s]None
#  #################--- [85%] [0.01s]None
#  ###################- [95%] [0.01s]None
# None
#  #################### [99%] [0.01s]
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9400
# M0 - Kappa        : 0.6670
# M0 - Precision: 0.7778
# M0 - Recall: 0.6364
# M0 - F1 score: 0.7000
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.00
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9400
# M0 - Kappa        : 0.6670
# M0 - Precision: 0.7778
# M0 - Recall: 0.6364
# M0 - F1 score: 0.7000
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.00
# M0 - Total time    (s)  : 0.00
# Kappa: 0.6428571428571426
# G-Mean: 0.6428571428571426
# Accuracy: 0.7071067811865476
# Recall: 0.95
# Precision: 0.5
# F1 Score: 1.0
# 127.0.0.1 - - [30/Apr/2021 22:14:48] "GET /predict/100 HTTP/1.1" 200 -
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  -------------------- [0%] [0.00s]None
#  #------------------- [5%] [0.00s]None
#  ###----------------- [15%] [0.00s]None
#  #####--------------- [25%] [0.00s]None
#  #######------------- [35%] [0.00s]None
#  ########------------ [40%] [0.00s]None
#  #########----------- [45%] [0.01s]None
#  ##########---------- [50%] [0.01s]None
#  ############-------- [60%] [0.01s]None
# None
#  ##############------ [70%] [0.01s]None
#  ################---- [80%] [0.01s]None
#  #################--- [85%] [0.01s]None
#  ##################-- [90%] [0.01s]None
#  ###################- [95%] [0.01s]None
#  #################### [99%] [0.01s]
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9700
# M0 - Kappa        : 0.7115
# M0 - Precision: 0.6667
# M0 - Recall: 0.8000
# M0 - F1 score: 0.7273
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9700
# M0 - Kappa        : 0.7115
# M0 - Precision: 0.6667
# M0 - Recall: 0.8000
# M0 - F1 score: 0.7273
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# Kappa: 0.6428571428571426
# G-Mean: 0.6428571428571426
# Accuracy: 0.9733285267845752
# Recall: 0.95
# Precision: 1.0
# F1 Score: 0.5
# 127.0.0.1 - - [30/Apr/2021 22:15:05] "GET /predict/100 HTTP/1.1" 200 -
#    Mean of the integrated profile  ...  target_class
# 0                      121.156250  ...             0
# 1                       76.968750  ...             0
# 2                      130.585938  ...             0
# 3                       84.804688  ...             0
# 4                      109.406250  ...             0
#
# [5 rows x 9 columns]
ve": 14.51918499, "skewnessOfTheIntegratedProfile": 8.210833977, "standardDeviationOfTheDMSNRCurve": 36.37485482, "standardDeviationOfTheIntegratedProfile": 34.44594596, "targetClass": 1, "yPred": 1}, "-MZYelQIyz7W-MdY0gw5": {"excessKurtosisOfTheDMSNRCurve": 23.65845263, "excessKurtosisOfTheIntegratedProfile": 0.216697007, "meanOfTheDMSNRCurve": 0.447324415, "meanOfTheIntegratedProfile": 122.25, "skewnessOfTheDMSNRCurve": 596.8527412999999, "skewnessOfTheIntegratedProfile": 1.500288742, "standardDeviationOfTheDMSNRCurve": 9.131228412, "standardDeviationOfTheIntegratedProfile": 35.21984526, "targetClass": 0, "yPred": 0}, "-MZYelQN8X9rynj1n3KW": {"excessKurtosisOfTheDMSNRCurve": 12.47973061, "excessKurtosisOfTheIntegratedProfile": 0.030621693, "meanOfTheDMSNRCurve": 1.802675585, "meanOfTheIntegratedProfile": 119.3046875, "skewnessOfTheDMSNRCurve": 176.7102012, "skewnessOfTheIntegratedProfile": -0.347364661, "standardDeviationOfTheDMSNRCurve": 15.65988397, "standardDeviationOfTheIntegratedProfile": 51.31239473, "targetClass": 0, "yPred": 0}, "-MZYelQVplsSL7-GCaJy": {"excessKurtosisOfTheDMSNRCurve": 2.60805282, "excessKurtosisOfTh ...
# {'-MZYekyPXsrn-DaPk1-s': {'excessKurtosisOfTheDMSNRCurve': 7.09898352, 'excessKurtosisOfTheIntegratedProfile': 0.003680461, 'meanOfTheDMSNRCurve': 4.235785953, 'meanOfTheIntegratedProfile': 126.890625, 'skewnessOfTheDMSNRCurve': 54.34457468, 'skewnessOfTheIntegratedProfile': -0.274938662, 'standardDeviationOfTheDMSNRCurve': 24.84994277, 'standardDeviationOfTheIntegratedProfile': 54.59069781, 'targetClass': 0, 'yPred': 0}, '-MZYekybZkIqBixFpsDK': {'excessKurtosisOfTheDMSNRCurve': 6.608765622999999, 'excessKurtosisOfTheIntegratedProfile': 0.7279405959999999, 'meanOfTheDMSNRCurve': 4.3285953180000005, 'meanOfTheIntegratedProfile': 94.4609375, 'skewnessOfTheDMSNRCurve': 48.07896235, 'skewnessOfTheIntegratedProfile': 3.6314223130000003, 'standardDeviationOfTheDMSNRCurve': 23.49937489, 'standardDeviationOfTheIntegratedProfile': 33.18200339, 'targetClass': 0, 'yPred': 1}, '-MZYekyldJ2ucByp0iC6': {'excessKurtosisOfTheDMSNRCurve': 9.112675945, 'excessKurtosisOfTheIntegratedProfile': 0.43822078700000006, 'meanOfTheDMSNRCurve': 2.43729097, 'meanOfTheIntegratedProfile': 97.265625, 'skewnessOfTheDMSNRCurve': 86.14917564, 'skewnessOfTheIntegratedProfile': 1.192393062, 'standardDeviationOfTheDMSNRCurve': 20.5490338, 'standardDeviationOfTheIntegratedProfile': 38.2915388, 'targetClass': 0, 'yPred': 0}, '-MZYekymyEXBJ-qHLYg7': {'excessKurtosisOfTheDMSNRCurve': 13.37998477, 'excessKurtosisOfTheIntegratedProfile': 0.7395630059999999, 'meanOfTheDMSNRCur
...             1
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 1
# <class 'numpy.int64'>
# -MZYelQ3xuvDPXi131BH
# {'excessKurtosisOfTheDMSNRCurve': 3.623148117, 'excessKurtosisOfTheIntegratedProfile': 1.9746109619999999, 'meanOfTheDMSNRCurve': 12.33277592, 'meanOfTheIntegratedProfile': 75.734375, 'skewnessOfTheDMSNRCurve': 14.51918499, 'skewnessOfTheIntegratedProfile': 8.210833977, 'standardDeviationOfTheDMSNRCurve': 36.37485482, 'standardDeviationOfTheIntegratedProfile': 34.44594596, 'targetClass': 1, 'yPred': 1}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             3.623148  ...     1.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                       75.734375  ...             1
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 1
# <class 'numpy.int64'>
# -MZYelQIyz7W-MdY0gw5
# {'excessKurtosisOfTheDMSNRCurve': 23.65845263, 'excessKurtosisOfTheIntegratedProfile': 0.216697007, 'meanOfTheDMSNRCurve': 0.447324415, 'meanOfTheIntegratedProfile': 122.25, 'skewnessOfTheDMSNRCurve': 596.8527412999999, 'skewnessOfTheIntegratedProfile': 1.500288742, 'standardDeviationOfTheDMSNRCurve': 9.131228412, 'standardDeviationOfTheIntegratedProfile': 35.21984526, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                            23.658453  ...     0.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                          122.25  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYelQN8X9rynj1n3KW
# {'excessKurtosisOfTheDMSNRCurve': 12.47973061, 'excessKurtosisOfTheIntegratedProfile': 0.030621693, 'meanOfTheDMSNRCurve': 1.802675585, 'meanOfTheIntegratedProfile': 119.3046875, 'skewnessOfTheDMSNRCurve': 176.7102012, 'skewnessOfTheIntegratedProfile': -0.347364661, 'standardDeviationOfTheDMSNRCurve': 15.65988397, 'standardDeviationOfTheIntegratedProfile': 51.31239473, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                            12.479731  ...     0.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                      119.304688  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYelQVplsSL7-GCaJy
# {'excessKurtosisOfTheDMSNRCurve': 2.60805282, 'excessKurtosisOfTheIntegratedProfile': -0.19132243699999998, 'meanOfTheDMSNRCurve': 19.31939799, 'meanOfTheIntegratedProfile': 142.1328125, 'skewnessOfTheDMSNRCurve': 5.065897497, 'skewnessOfTheIntegratedProfile': -0.15949297199999998, 'standardDeviationOfTheDMSNRCurve': 55.31542261, 'standardDeviationOfTheIntegratedProfile': 50.17817801, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             2.608053  ...     0.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                      142.132812  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYelgyKvupIC2eZmCL
# {'excessKurtosisOfTheDMSNRCurve': 3.882441397, 'excessKurtosisOfTheIntegratedProfile': 3.888586052, 'meanOfTheDMSNRCurve': 12.45986622, 'meanOfTheIntegratedProfile': 41.3203125, 'skewnessOfTheDMSNRCurve': 14.73798107, 'skewnessOfTheIntegratedProfile': 19.89897188, 'standardDeviationOfTheDMSNRCurve': 44.0085606, 'standardDeviationOfTheIntegratedProfile': 32.3964537, 'targetClass': 1, 'yPred': 1}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             3.882441  ...     1.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                       41.320312  ...             1
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 1
# <class 'numpy.int64'>
# -MZYelh8m7wJcCWXxiaa
# {'excessKurtosisOfTheDMSNRCurve': 13.95621135, 'excessKurtosisOfTheIntegratedProfile': 0.644002347, 'meanOfTheDMSNRCurve': 1.193979933, 'meanOfTheIntegratedProfile': 85.84375, 'skewnessOfTheDMSNRCurve': 223.6619506, 'skewnessOfTheIntegratedProfile': 1.754021675, 'standardDeviationOfTheDMSNRCurve': 13.05605988, 'standardDeviationOfTheIntegratedProfile': 39.09292565, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0
 'targetClass': 1, 'yPred': 1}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             5.862879  ...     1.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                       68.101562  ...             1
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 1
# <class 'numpy.int64'>
# -MZYepCy-koxrYScqOPm
# {'excessKurtosisOfTheDMSNRCurve': 7.949384567999999, 'excessKurtosisOfTheIntegratedProfile': -0.071590538, 'meanOfTheDMSNRCurve': 3.439799331, 'meanOfTheIntegratedProfile': 123.921875, 'skewnessOfTheDMSNRCurve': 77.62207013, 'skewnessOfTheIntegratedProfile': -0.18483503399999998, 'standardDeviationOfTheDMSNRCurve': 18.26483604, 'standardDeviationOfTheIntegratedProfile': 49.70972135, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             7.949385  ...     0.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                      123.921875  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYepD4As15vRH9fYjH
# {'excessKurtosisOfTheDMSNRCurve': 1.781491554, 'excessKurtosisOfTheIntegratedProfile': 1.202375439, 'meanOfTheDMSNRCurve': 31.8361204, 'meanOfTheIntegratedProfile': 105.140625, 'skewnessOfTheDMSNRCurve': 1.909746524, 'skewnessOfTheIntegratedProfile': 3.6392460189999998, 'standardDeviationOfTheDMSNRCurve': 59.58570652, 'standardDeviationOfTheIntegratedProfile': 36.7161269, 'targetClass': 1, 'yPred': 1}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             1.781492  ...     1.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                      105.140625  ...             1
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 0
# <class 'numpy.int64'>
# -MZYepDSXd_LGlDUK6jU
# {'excessKurtosisOfTheDMSNRCurve': 7.51362971, 'excessKurtosisOfTheIntegratedProfile': 0.022625611, 'meanOfTheDMSNRCurve': 3.340301003, 'meanOfTheIntegratedProfile': 140.8515625, 'skewnessOfTheDMSNRCurve': 63.49014084, 'skewnessOfTheIntegratedProfile': -0.016207911999999998, 'standardDeviationOfTheDMSNRCurve': 21.28494564, 'standardDeviationOfTheIntegratedProfile': 48.92981099, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                              7.51363  ...     0.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                      140.851562  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYepDaXQizYw8QuEvg
# {'excessKurtosisOfTheDMSNRCurve': -0.011732848999999998, 'excessKurtosisOfTheIntegratedProfile': 4.502423884, 'meanOfTheDMSNRCurve': 135.3586957, 'meanOfTheIntegratedProfile': 13.953125, 'skewnessOfTheDMSNRCurve': -0.186721387, 'skewnessOfTheIntegratedProfile': 20.0925461, 'standardDeviationOfTheDMSNRCurve': 55.87221984, 'standardDeviationOfTheIntegratedProfile': 39.75331342, 'targetClass': 1, 'yPred': 1}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                            -0.011733  ...     1.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                       13.953125  ...             1
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 1
# <class 'numpy.int64'>
# -MZYepEFaqIweIdDIdx_
# {'excessKurtosisOfTheDMSNRCurve': 12.12466367, 'excessKurtosisOfTheIntegratedProfile': 0.19402785399999997, 'meanOfTheDMSNRCurve': 1.4983277590000001, 'meanOfTheIntegratedProfile': 131.4453125, 'skewnessOfTheDMSNRCurve': 183.295974, 'skewnessOfTheIntegratedProfile': -0.297258421, 'standardDeviationOfTheDMSNRCurve': 12.96847853, 'standardDeviationOfTheIntegratedProfile': 50.27499512, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                            12.124664  ...     0.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                      131.445312  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYepVdNlAEmhq9_WpE
# {'excessKurtosisOfTheDMSNRCurve': 6.0102949379999995, 'excessKurtosisOfTheIntegratedProfile': 0.40933563799999995, 'meanOfTheDMSNRCurve': 4.637959866, 'meanOfTheIntegratedProfile': 102.5234375, 'skewnessOfTheDMSNRCurve': 41.77222657, 'skewnessOfTheIntegratedProfile': 0.46482025200000004, 'standardDeviationOfTheDMSNRCurve': 22.15678846, 'standardDeviationOfTheIntegratedProfile': 48.61406767, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             6.010295  ...     0.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                      102.523438  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYepVh31cd2TR0cHJ6
# {'excessKurtosisOfTheDMSNRCurve': 3.478214342, 'excessKurtosisOfTheIntegratedProfile': -0.34761224799999996, 'meanOfTheDMSNRCurve': 13.32274247, 'meanOfTheIntegratedProfile': 150.6796875, 'skewnessOfTheDMSNRCurve': 11.4179663, 'skewnessOfTheIntegratedProfile': -0.7253326109999999, 'standardDeviationOfTheDMSNRCurve': 44.87332059, 'standardDeviationOfTheIntegratedProfile': 59.34643176, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             3.478214  ...     0.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                      150.679688  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYepXS-DTCnq4sxdpP
# {'excessKurtosisOfTheDMSNRCurve': 0.105358058, 'excessKurtosisOfTheIntegratedProfile': 4.578745511, 'meanOfTheDMSNRCurve': 110.9565217, 'meanOfTheIntegratedProfile': 34.0859375, 'skewnessOfTheDMSNRCurve': -1.003129925, 'skewnessOfTheIntegratedProfile': 25.10418984, 'standardDeviationOfTheDMSNRCurve': 79.35646125, 'standardDeviationOfTheIntegratedProfile': 32.45598639, 'targetClass': 1, 'yPred': 1}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             0.105358  ...     1.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                       34.085938  ...             1
#
# [1 rows x 9 columns]
# Features:
# ...
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                       118.21875  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYgSf3UaGaIoEnrfPk
# {'excessKurtosisOfTheDMSNRCurve': 12.21922486, 'excessKurtosisOfTheIntegratedProfile': -0.14612820599999998, 'meanOfTheDMSNRCurve': 1.440635452, 'meanOfTheIntegratedProfile': 141.5859375, 'skewnessOfTheDMSNRCurve': 175.4697118, 'skewnessOfTheIntegratedProfile': -0.33671935299999994, 'standardDeviationOfTheDMSNRCurve': 13.31684832, 'standardDeviationOfTheIntegratedProfile': 52.15249984, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                            12.219225  ...     0.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                      141.585938  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYgSf41xEEuQemBLRH
# {'excessKurtosisOfTheDMSNRCurve': 1.180934251, 'excessKurtosisOfTheIntegratedProfile': 5.455234827999999, 'meanOfTheDMSNRCurve': 66.80602007, 'meanOfTheIntegratedProfile': 19.03125, 'skewnessOfTheDMSNRCurve': 1.31928722, 'skewnessOfTheIntegratedProfile': 30.53455456, 'standardDeviationOfTheDMSNRCurve': 59.00179265, 'standardDeviationOfTheIntegratedProfile': 33.35414552, 'targetClass': 1, 'yPred': 1}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             1.180934  ...     1.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                        19.03125  ...             1
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 1
# <class 'numpy.int64'>
# -MZYgSwYD6ZbAw3DdkhQ
# {'excessKurtosisOfTheDMSNRCurve': 7.803411722000001, 'excessKurtosisOfTheIntegratedProfile': 0.013689465, 'meanOfTheDMSNRCurve': 2.831103679, 'meanOfTheIntegratedProfile': 121.515625, 'skewnessOfTheDMSNRCurve': 82.44600034, 'skewnessOfTheIntegratedProfile': -0.37891878700000003, 'standardDeviationOfTheDMSNRCurve': 15.45004581, 'standardDeviationOfTheIntegratedProfile': 56.70138121, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             7.803412  ...     0.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                      121.515625  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYgSwkMZrU-eu7l6bs
# {'excessKurtosisOfTheDMSNRCurve': 1.6825808219999998, 'excessKurtosisOfTheIntegratedProfile': 0.358277487, 'meanOfTheDMSNRCurve': 38.213210700000005, 'meanOfTheIntegratedProfile': 112.9296875, 'skewnessOfTheDMSNRCurve': 0.8716394670000001, 'skewnessOfTheIntegratedProfile': 0.13822305, 'standardDeviationOfTheDMSNRCurve': 81.61886622, 'standardDeviationOfTheIntegratedProfile': 48.48021239, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             1.682581  ...     0.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                      112.929688  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYgSx4HFzMSAG9CqDW
# {'excessKurtosisOfTheDMSNRCurve': -0.205904946, 'excessKurtosisOfTheIntegratedProfile': 6.653031114, 'meanOfTheDMSNRCurve': 127.3377926, 'meanOfTheIntegratedProfile': 22.96875, 'skewnessOfTheDMSNRCurve': -1.154987786, 'skewnessOfTheIntegratedProfile': 47.96902735, 'standardDeviationOfTheDMSNRCurve': 82.08952579, 'standardDeviationOfTheIntegratedProfile': 28.21013157, 'targetClass': 1, 'yPred': 1}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                            -0.205905  ...     1.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                        22.96875  ...             1
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 1
# <class 'numpy.int64'>
# -MZYgSxJGold3uUZceiW
# {'excessKurtosisOfTheDMSNRCurve': 8.704686005, 'excessKurtosisOfTheIntegratedProfile': 0.48675016299999996, 'meanOfTheDMSNRCurve': 2.6797658859999998, 'meanOfTheIntegratedProfile': 91.734375, 'skewnessOfTheDMSNRCurve': 91.08918916, 'skewnessOfTheIntegratedProfile': 2.779660778, 'standardDeviationOfTheDMSNRCurve': 16.47325669, 'standardDeviationOfTheIntegratedProfile': 35.36340012, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             8.704686  ...     0.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                       91.734375  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYgSxuOT140dD-pKkD
# {'excessKurtosisOfTheDMSNRCurve': 2.507846989, 'excessKurtosisOfTheIntegratedProfile': 3.5450515510000002, 'meanOfTheDMSNRCurve': 24.8319398, 'meanOfTheIntegratedProfile': 46.015625, 'skewnessOfTheDMSNRCurve': 5.088718665, 'skewnessOfTheIntegratedProfile': 19.49501343, 'standardDeviationOfTheDMSNRCurve': 61.51964379, 'standardDeviationOfTheIntegratedProfile': 30.47565226, 'targetClass': 1, 'yPred': 1}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             2.507847  ...     1.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                       46.015625  ...             1
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 1
# <class 'numpy.int64'>
# -MZYgTExkTWmX_jw4f85
# {'excessKurtosisOfTheDMSNRCurve': 5.6258524329999995, 'excessKurtosisOfTheIntegratedProfile': 0.13194109, 'meanOfTheDMSNRCurve': 6.193979933, 'meanOfTheIntegratedProfile': 128.7734375, 'skewnessOfTheDMSNRCurve': 32.67753762, 'skewnessOfTheIntegratedProfile': -0.104736501, 'standardDeviationOfTheDMSNRCurve': 30.50712671, 'standardDeviationOfTheIntegratedProfile': 51.19665133, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             5.625852  ...     0.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                      128.773438  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYgTFDvNFcd9r0AZTb
# {'excessKurtosisOfTheDMSNRCurve': 2.55538357, 'excessKurtosisOfTheIntegratedProfile': 5.273403641, 'meanOfTheDMSNRCurve': 24.15635452, 'meanOfTheIntegratedProfile': 30.8671875, 'skewnessOfTheDMSNRCurve': 6.692879465, 'skewnessOfTheIntegratedProfile': 32.67567927, 'standardDeviationOfTheDMSNRCurve': 50.80910369, 'standardDeviationOfTheIntegratedProfile': 29.94588116, 'targetClass': 1, 'yPred': 1}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             2.555384  ...     1.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                       30.867188  ...             1
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 1
# <class 'numpy.int64'>
# -MZYgTG_N9g-JL3CKM8g
# {'excessKurtosisOfTheDMSNRCurve': 10.01359091, 'excessKurtosisOfTheIntegratedProfile': 1.153606583, 'meanOfTheDMSNRCurve': 2.099498328, 'meanOfTheIntegratedProfile': 73.6328125, 'skewnessOfTheDMSNRCurve': 140.8941513, 'skewnessOfTheIntegratedProfile': 4.161082483, 'standardDeviationOfTheDMSNRCurve': 13.05747392, 'standardDeviationOfTheIntegratedProfile': 35.46121805, 'targetClass': 0, 'yPred': 1}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                            10.013591  ...     1.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                       73.632812  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYgTTAM_e4N9gR_KgU
# {'excessKurtosisOfTheDMSNRCurve': 7.945836773, 'excessKurtosisOfTheIntegratedProfile': 0.482742082, 'meanOfTheDMSNRCurve': 3.22909699, 'meanOfTheIntegratedProfile': 88.921875, 'skewnessOfTheDMSNRCurve': 65.59594432, 'skewnessOfTheIntegratedProfile': 0.923327947, 'standardDeviationOfTheDMSNRCurve': 23.49616114, 'standardDeviationOfTheIntegratedProfile': 41.31464809, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             7.945837  ...     0.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                       88.921875  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYgTW-NvKe4B9lshOI
# {'excessKurtosisOfTheDMSNRCurve': 6.079427667999999, 'excessKurtosisOfTheIntegratedProfile': 0.397100984, 'meanOfTheDMSNRCurve': 5.049331104, 'meanOfTheIntegratedProfile': 111.5546875, 'skewnessOfTheDMSNRCurve': 37.03251195, 'skewnessOfTheIntegratedProfile': 1.244277517, 'standardDeviationOfTheDMSNRCurve': 29.5233892, 'standardDeviationOfTheIntegratedProfile': 43.97083703, 'targetClass': 0, 'yPred': 0}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             6.079428  ...     0.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                      111.554688  ...             0
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 0
# <class 'numpy.int64'>
# -MZYgTX191--spJtWoQL
# {'excessKurtosisOfTheDMSNRCurve': 0.9888477609999999, 'excessKurtosisOfTheIntegratedProfile': 6.793773206, 'meanOfTheDMSNRCurve': 72.12541806, 'meanOfTheIntegratedProfile': 25.828125, 'skewnessOfTheDMSNRCurve': 0.136513894, 'skewnessOfTheIntegratedProfile': 48.16864374, 'standardDeviationOfTheDMSNRCurve': 70.63552397, 'standardDeviationOfTheIntegratedProfile': 29.67930397, 'targetClass': 1, 'yPred': 1}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             0.988848  ...     1.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                       25.828125  ...             1
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 1
# <class 'numpy.int64'>
# -MZYgU4bSUWEuy5IKKws
# {'excessKurtosisOfTheDMSNRCurve': 0.6940736959999999, 'excessKurtosisOfTheIntegratedProfile': 1.940449831, 'meanOfTheDMSNRCurve': 75.96655518, 'meanOfTheIntegratedProfile': 68.90625, 'skewnessOfTheDMSNRCurve': -0.785507585, 'skewnessOfTheIntegratedProfile': 3.891114308, 'standardDeviationOfTheDMSNRCurve': 79.82689603, 'standardDeviationOfTheIntegratedProfile': 50.1353539, 'targetClass': 1, 'yPred': 1}
#    Excess kurtosis of the DM-SNR curve  ...  y_pred
# 0                             0.694074  ...     1.0
#
# [1 rows x 10 columns]
#    Mean of the integrated profile  ...  target_class
# 0                        68.90625  ...             1
#
# [1 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 1
# <class 'numpy.int64'>
# 127.0.0.1 - - [30/Apr/2021 22:23:00] "GET /test-with-other-classifier/smote_bagging HTTP/1.1" 200 -
